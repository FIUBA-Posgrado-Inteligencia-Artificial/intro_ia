# %% [markdown]
# # Regularización - Dataset de Vehículos

# %% [markdown]
# En éste notebook se analizará el impacto de la regularización de Ridge, Lasso y ElasticNet sobre un dataset de precios de vehículos usados. Realizaremos inicialmente un análisis exploratorio del dataset, una etapa de feature selection y por último elaboraremos los modelos.

# %% [markdown]
# ## Importamos las Librerías

# %%
import pandas as pd
import numpy as np

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# Preprocesado y modelado
# ==============================================================================
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV

# Configuración matplotlib
# ==============================================================================
plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')

# %% [markdown]
# ## Cargamos los datos

# %%
data=pd.read_csv("data/car data.csv")

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# Las features del dataset son:
# * Car_Name
# * Year
# * Selling_Price
# * Present_Price
# * Kms_Driven
# * Fuel_Type
# * Seller_Type
# * Transmission
# * Owner
#
# Pueden consultar en la [fuente original](CarDekho.com) más información sobre el dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# Como no tenemos valores faltantes, no nos tenemos que preocupar por estrategias de imputación.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.barplot(x='Owner',y='Selling_Price',data=data,palette='spring')
plt.show()

# %%
sns.barplot(x='Fuel_Type',y='Selling_Price',data=data,palette='spring')
plt.show()

# %%
sns.barplot(x='Seller_Type',y='Selling_Price',data=data,palette='spring')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='Present_Price',y='Selling_Price',data=data)
plt.show()

# %%
sns.lmplot(x='Kms_Driven',y='Selling_Price',data=data)
plt.show()

# %% [markdown]
# ### Estudio de Correlación

# %%
corr_matrix = data.corr(method='pearson')

# %%
# Heatmap matriz de correlaciones
# ==============================================================================
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(18, 18))

sns.heatmap(
    corr_matrix,
    square    = True,
    ax        = ax
)

ax.tick_params(labelsize = 10)

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
# Vamos a crear una nueva feature que en vez de almacenar el año del modelo, almacene los años transcurridos al presente.
# De este modo tiene una relación más directa con el precio de venta actual.

data['vehicle_age'] = 2021 - data['Year']

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  vehicle_age
# 0      Dealer       Manual      0            7
# 1      Dealer       Manual      0            8
# 2      Dealer       Manual      0            4
# 3      Dealer       Manual      0           10
# 4      Dealer       Manual      0            7

# %%
data.drop(columns=['Year'],inplace=True)

# %%
# Vamos a codificar las variables categóricas usando get_dummies(). Esto generalmente trae inconvenientes en los modelos lineales.
data=pd.get_dummies(data,columns=['Fuel_Type','Transmission','Seller_Type'], drop_first=True)

# %%
data.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Kms_Driven  Owner  vehicle_age  \
# 0     ritz           3.35           5.59       27000      0            7
# 1      sx4           4.75           9.54       43000      0            8
# 2     ciaz           7.25           9.85        6900      0            4
# 3  wagon r           2.85           4.15        5200      0           10
# 4    swift           4.60           6.87       42450      0            7
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Manual  \
# 0                 0                 1                    1
# 1                 1                 0                    1
# 2                 0                 1                    1
# 3                 0                 1                    1
# 4                 1                 0                    1
#
#    Seller_Type_Individual
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# ## Split del Dataset

# %%
# División de los datos en train y test

X = data.drop(columns=['Car_Name','Selling_Price'],axis=1)
y = data['Selling_Price']

X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        y.values.reshape(-1,1),
                                        train_size   = 0.7,
                                        random_state = 1234,
                                        shuffle      = True
                                    )

# %%
X_train.shape
# Out:
# (210, 8)

# %%
y_train.shape
# Out:
# (210, 1)

# %%
# Como la regularización de Ridge y Lasso operan sobre las magnitudes de los parámetros, es necesario estandarizar las
# features para que tengan igual rango de escala.

from sklearn.preprocessing import StandardScaler

x_scaler = StandardScaler()
y_scaler = StandardScaler()

# Colocamos las features de X a escalar
x_scale = ['Present_Price','Kms_Driven']

# Escalamos el dataset de entrenamiento haciendo un fit y transform del scaler
X_train[x_scale] = x_scaler.fit_transform(X_train[x_scale])
y_train = y_scaler.fit_transform(y_train)

# Transformamos el dataset de test (no hacemos fit)
X_test[x_scale] = x_scaler.transform(X_test[x_scale])
y_test = y_scaler.transform(y_test)

# %%
X_train.describe()
# Out:
#        Present_Price    Kms_Driven       Owner  vehicle_age  Fuel_Type_Diesel  \
# count   2.100000e+02  2.100000e+02  210.000000    210.00000        210.000000
# mean    6.767074e-17  7.612958e-17    0.052381      7.37619          0.190476
# std     1.002389e+00  1.002389e+00    0.280326      2.81595          0.393615
# min    -7.978525e-01 -8.947272e-01    0.000000      4.00000          0.000000
# 25%    -7.134901e-01 -5.085205e-01    0.000000      5.00000          0.000000
# 50%    -8.997767e-02 -1.316889e-01    0.000000      7.00000          0.000000
# 75%     2.002070e-01  2.176082e-01    0.000000      8.75000          0.000000
# max     9.345422e+00  1.114335e+01    3.000000     18.00000          1.000000
#
#        Fuel_Type_Petrol  Transmission_Manual  Seller_Type_Individual
# count        210.000000           210.000000              210.000000
# mean           0.800000             0.885714                0.357143
# std            0.400956             0.318918                0.480302
# min            0.000000             0.000000                0.000000
# 25%            1.000000             1.000000                0.000000
# 50%            1.000000             1.000000                0.000000
# 75%            1.000000             1.000000                1.000000
# max            1.000000             1.000000                1.000000

# %% [markdown]
# ## Modelos

# %% [markdown]
# A continuación, experimentaremos con modelos de regresión lineal estándar y modelos regularizados con Ridge, Lasso y ElasticNet.

# %% [markdown]
# ### Regresión Lineal

# %%
# Creación y entrenamiento del modelo

modelo = LinearRegression(normalize=True)
modelo.fit(X = X_train, y = y_train)
# Out:
# /home/nicolas/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# LinearRegression(normalize=True)

# %%
# Coeficientes del modelo

df_coeficientes = pd.DataFrame(
                        {'predictor': X_train.columns,
                         'coef': modelo.coef_.flatten()}
                  )

fig, ax = plt.subplots(figsize=(20, 10))
ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')
plt.xticks(rotation=90, ha='right', size=10)
ax.set_xlabel('feature')
ax.set_ylabel('weights')
ax.set_title('Parámetros del modelo');
# Out:
# <ipython-input-29-dc4a4f86d0b1>:9: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')

# %%
# Predicciones test

predicciones = modelo.predict(X=X_test)
predicciones = predicciones.flatten()
predicciones[:10]
# Out:
# array([-0.1934469 , -0.87570821, -0.44260185, -0.19844518, -0.55493475,
#        -0.53241886,  0.52436343,  0.29109236, -0.06172471, -0.67474663])

# %%
# Error de test del modelo. Uso rmse para mantener la misma escala que la variable a predecir

rmse_ols = mean_squared_error(
            y_true  = y_test,
            y_pred  = predicciones,
            squared = False
           )

print(f"El error (rmse) de test es: {rmse_ols}")
# Out:
# El error (rmse) de test es: 0.39484615631781866

# %%
from sklearn import metrics

R2 = metrics.r2_score(y_test, predicciones)

# %%
R2
# Out:
# 0.8586540632817556

# %%
fig = plt.figure(figsize=(10,10))
  
sns.distplot((y_test - predicciones), bins = 20)

fig.suptitle('Análisis de Residuos', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Análisis de Residuos')

# %%
y_test.shape
# Out:
# (91, 1)

# %%
fig = plt.figure(figsize=(10,10))
fig.suptitle('residuos')

plt.xlabel('y_test')

plt.ylabel('residuos')

plt.scatter(y_test,y_test-predicciones.reshape(-1, 1))

# %% [markdown]
# ### Ridge Regression

# %%
# Creación y entrenamiento del modelo. Scikit-Learn usa Cross Validation para encontrar el valor óptimo de alpha
# (lambda en los desarrollos de teoría). Puede ser problemático con series de tiempo.

modelo = RidgeCV(
            alphas          = np.logspace(-10, 2, 200),
            fit_intercept   = True,
            normalize       = True,
            store_cv_values = True
         )

_ = modelo.fit(X = X_train, y = y_train)

# %%
# Evolución de los parámetros en función de alpha

alphas = modelo.alphas
coefs = []

for alpha in alphas:
    modelo_temp = Ridge(alpha=alpha, fit_intercept=False, normalize=True)
    modelo_temp.fit(X_train, y_train)
    coefs.append(modelo_temp.coef_.flatten())

fig, ax = plt.subplots(figsize=(7, 3.84))
ax.plot(alphas, coefs)
ax.set_xscale('log')
ax.set_xlabel('log(alpha)')
ax.set_ylabel('parámetros')
ax.set_title('Parámetros del modelo en función de la regularización');
plt.axis('tight')
plt.show()

# %%
# Evolución del error de validación cruzada en función de alpha

# modelo.cv_values almacena el mse de cv para cada valor de alpha. Tiene dimensiones (n_samples, n_targets, n_alphas)

mse_cv = modelo.cv_values_.reshape((-1, 200)).mean(axis=0)
mse_sd = modelo.cv_values_.reshape((-1, 200)).std(axis=0)

# Se aplica la raíz cuadrada para pasar de mse a rmse
rmse_cv = np.sqrt(mse_cv)
rmse_sd = np.sqrt(mse_sd)

# Se identifica el óptimo y el óptimo + 1std
min_rmse     = np.min(rmse_cv)
optimo       = modelo.alphas[np.argmin(rmse_cv)]

# Gráfico del error +- 1 desviación estándar (fill area)
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(modelo.alphas, rmse_cv)
ax.fill_between(
    modelo.alphas,
    rmse_cv + rmse_sd,
    rmse_cv - rmse_sd,
    alpha=0.2
)

ax.axvline(
    x         = optimo,
    c         = "gray",
    linestyle = '--',
    label     = 'óptimo'
)

ax.set_xscale('log')
ax.set_ylim([0,None])
ax.set_title('Evolución del error CV en función de la regularización')
ax.set_xlabel('alpha')
ax.set_ylabel('RMSE')
plt.legend();

# %%
# Mejor valor alpha encontrado

print(f"Mejor valor de alpha encontrado: {modelo.alpha_}")
# Out:
# Mejor valor de alpha encontrado: 0.11097524964120699

# %%
# Parámetros del modelo

df_coeficientes = pd.DataFrame(
                        {'predictor': X_train.columns,
                         'coef': modelo.coef_.flatten()}
                  )

fig, ax = plt.subplots(figsize=(20, 10))
ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')
plt.xticks(rotation=90, ha='right', size=10)
ax.set_xlabel('features')
ax.set_ylabel('parámetros')
ax.set_title('Parámetros del modelo');
# Out:
# <ipython-input-49-23fa78b24dda>:9: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')

# %%
# Predicciones test

predicciones = modelo.predict(X = X_test)
predicciones = predicciones.flatten()
predicciones[:10]
# Out:
# array([-0.18216986, -0.84268314, -0.3896394 , -0.15469533, -0.56530995,
#        -0.54496974,  0.54671476,  0.24627053, -0.06605414, -0.67201411])

# %%
# Error de test del modelo 

rmse_ridge = mean_squared_error(
                y_true  = y_test,
                y_pred  = predicciones,
                squared = False
             )

print(f"El error (rmse) de test es: {rmse_ridge}")
# Out:
# El error (rmse) de test es: 0.4292067586970795

# %%
R2 = metrics.r2_score(y_test, predicciones)

# %%
R2
# Out:
# 0.8329830289305579

# %% [markdown]
# ### Lasso Regression

# %%
modelo = LassoCV(
            alphas          = np.logspace(-10, 3, 200),
            normalize       = True,
            cv              = 10
         )

_ = modelo.fit(X = X_train, y = y_train.flatten())

# %%
# Evolución de los parámetros en función de alpha

alphas = modelo.alphas_
coefs = []

for alpha in alphas:
    modelo_temp = Lasso(alpha=alpha, fit_intercept=False, normalize=True)
    modelo_temp.fit(X_train, y_train)
    coefs.append(modelo_temp.coef_.flatten())

fig, ax = plt.subplots(figsize=(7, 3.84))
ax.plot(alphas, coefs)
ax.set_xscale('log')
ax.set_ylim([-0.5,None])
ax.set_xlabel('alpha')
ax.set_ylabel('parámetros')
ax.set_title('Coeficientes del modelo en función de la regularización');

# %%
# Número de features incluidas (parámetros !=0) en función de alpha

alphas = modelo.alphas_
n_predictores = []

for alpha in alphas:
    modelo_temp = Lasso(alpha=alpha, fit_intercept=False, normalize=True)
    modelo_temp.fit(X_train, y_train)
    coef_no_cero = np.sum(modelo_temp.coef_.flatten() != 0)
    n_predictores.append(coef_no_cero)

fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(alphas, n_predictores)
ax.set_xscale('log')
ax.set_ylim([-0.5,None])
ax.set_xlabel('alpha')
ax.set_ylabel('nº parámetros')
ax.set_title('Features incluidas en función de la regularización')
# Out:
# Text(0.5, 1.0, 'Features incluidas en función de la regularización')

# %%
# Evolución del error de validación cruzada en función de alpha

mse_cv = modelo.mse_path_.mean(axis=1)
mse_sd = modelo.mse_path_.std(axis=1)

# Se aplica la raíz cuadrada para pasar de mse a rmse
rmse_cv = np.sqrt(mse_cv)
rmse_sd = np.sqrt(mse_sd)

# Se identifica el óptimo y el óptimo + 1std
min_rmse     = np.min(rmse_cv)
optimo       = modelo.alphas_[np.argmin(rmse_cv)]

# Gráfico del error +- 1 desviación estándar
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(modelo.alphas_, rmse_cv)
ax.fill_between(
    modelo.alphas_,
    rmse_cv + rmse_sd,
    rmse_cv - rmse_sd,
    alpha=0.2
)

ax.axvline(
    x         = optimo,
    c         = "gray",
    linestyle = '--',
    label     = 'óptimo'
)

ax.set_xscale('log')
ax.set_ylim([0,None])
ax.set_title('Evolución del error CV en función de la regularización')
ax.set_xlabel('alpha')
ax.set_ylabel('RMSE')
plt.legend()

# %%
# Mejor valor alpha encontrado

print(f"Mejor valor de alpha encontrado: {modelo.alpha_}")
# Out:
# Mejor valor de alpha encontrado: 0.003783462617131933

# %%
df_coeficientes = pd.DataFrame(
                        {'predictor': X_train.columns,
                         'coef': modelo.coef_.flatten()}
                  )

df_coeficientes[df_coeficientes.coef != 0]
# Out:
#                 predictor      coef
# 0           Present_Price  0.720739
# 3             vehicle_age -0.183456
# 4        Fuel_Type_Diesel  0.336913
# 6     Transmission_Manual -0.168311
# 7  Seller_Type_Individual -0.163132

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')
plt.xticks(rotation=90, ha='right', size=10)
ax.set_xlabel('features')
ax.set_ylabel('parámetros')
ax.set_title('Parámetros del modelo');
# Out:
# <ipython-input-64-e0d0a4da74c4>:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')

# %%
predicciones = modelo.predict(X=X_test)
predicciones = predicciones.flatten()
predicciones[:10]
# Out:
# array([-0.10336885, -0.81628673, -0.43246577, -0.3594793 , -0.51466481,
#        -0.50402371,  0.32142597,  0.23664061, -0.00466436, -0.49079019])

# %%
# Error de test del modelo 

rmse_lasso = mean_squared_error(
                y_true  = y_test,
                y_pred  = predicciones,
                squared = False
             )
print("")
print(f"El error (rmse) de test es: {rmse_lasso}")
# Out:
# El error (rmse) de test es: 0.42957255472774525

# %%
R2 = metrics.r2_score(y_test, predicciones)
R2
# Out:
# 0.8326982236338081

# %% [markdown]
# ### ElasticNet

# %%
modelo = ElasticNetCV(
            l1_ratio        = [0, 0.1, 0.5, 0.7, 0.9, 0.95, 0.99],
            alphas          = np.logspace(-10, 3, 200),
            normalize       = True,
            cv              = 10
         )
_ = modelo.fit(X = X_train, y = y_train.flatten())
# Out:
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86510385549302, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86495120640943, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86477377977415, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86456755392314, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86432785448751, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86404924848048, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86372542120475, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86291155396894, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86240306880468, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86181205422088, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.86112511704877, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.8603266912341, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.85939868552425, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.8583200741058, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.85706642098086, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.85560932739182, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.85391578989282, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.85194745468314, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.84965975152569, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.84700088792293, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.84391068116199, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.84031920230943, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.83614520216878, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.83129428453394, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.82565678669766, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.81910532101729, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.81149192430134, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.80264475375999, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.79236425915613, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.78041875049735, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.75041365638462, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.73167970230513, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.70991723583927, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.68463900763551, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.65528019304791, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.62118632684307, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.58159946140646, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.48230021899411, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.42040045772471, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.34858899744971, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.26530409796332, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.16874673012002, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.0568475639818, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.92723042735308, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.77717224705604, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.60355966227404, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.40284275048366, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.17098665196383, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91.90342234103397, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91.59499839439255, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91.23993637075363, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.83179335652669, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.36343635100658, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89.8270344388202, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89.21407606650091, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88.51542008793528, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87.72139037967179, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86.82192447039382, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85.80678639962146, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84.66585245356737, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83.38947501629467, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.96892407215373, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.39689765690545, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78.6680819415746, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76.7797294260965, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74.73221147677876, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72.52949149275685, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70.17946016304907, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67.69407731163233, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65.08927749787892, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.38461875731085, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.602683107168914, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.768268852969356, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.9074421268989, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.04653260366979, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.21116222505988, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.42538558146208, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.71099930747988, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.087050755516856, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.569549243172325, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.17136119307212, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.90225626409732, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.769065598665467, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.77591429616619, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.92449592035718, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.214364817340563, tolerance: 0.018773208855266597
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932561541807164, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932550454709205, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932540915955594, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932532709318073, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932525648761569, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.93251957423427, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932514348033804, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932509851689268, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932505983273808, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932502655095881, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932499791708842, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932497328203425, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932495208734924, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932493385257473, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932491816434846, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932490466703781, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932489305467438, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932488306402083, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932487446858586, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932486707354474, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932486071124098, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932485523745214, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932485052810573, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932484647643331, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932484299058912, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932483999155842, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932483741134993, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932483519147583, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Lautaro\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.932483328162059, tolerance: 0.01927530206079123
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
# Error medio de las 10 particiones por cada valor de alpha y l1_ratio 
mean_error_cv = modelo.mse_path_.mean(axis =2)

# El resultado es un array de dimensiones (n_l1_ratio, n_alpha) se convierte en un dataframe
df_resultados_cv = pd.DataFrame(
                        data   = mean_error_cv.flatten(),
                        index  = pd.MultiIndex.from_product(
                                    iterables = [modelo.l1_ratio, modelo.alphas_],
                                    names     = ['l1_ratio', 'modelo.alphas_']
                                 ),
                        columns = ["mse_cv"]
                    )

df_resultados_cv['rmse_cv'] = np.sqrt(df_resultados_cv['mse_cv'])
df_resultados_cv = df_resultados_cv.reset_index().sort_values('mse_cv', ascending = True)
df_resultados_cv
# Out:
#       l1_ratio  modelo.alphas_    mse_cv   rmse_cv
# 687       0.70        0.002073  0.145649  0.381640
# 686       0.70        0.002409  0.145908  0.381979
# 489       0.50        0.001534  0.146214  0.382379
# 488       0.50        0.001783  0.146230  0.382400
# 688       0.70        0.001783  0.146429  0.382660
# ...        ...             ...       ...       ...
# 1034      0.95        6.010277  1.006447  1.003218
# 1033      0.95        6.985880  1.006447  1.003218
# 1032      0.95        8.119845  1.006447  1.003218
# 1045      0.95        1.148951  1.006447  1.003218
# 434       0.50        6.010277  1.006447  1.003218
#
# [1400 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df_resultados_cv.groupby('l1_ratio')['rmse_cv'].min().plot(ax = ax)
ax.set_title('Evolución del error CV en función de la l1_ratio')
ax.set_xlabel('l1_ratio')
ax.set_ylabel('rmse_cv');

# %%
# Mejor valor alpha y l1_ratio_ encontrado

print(f"Mejor valor de alpha encontrado: {modelo.alpha_}")
print(f"Mejor valor de l1_ratio encontrado: {modelo.l1_ratio_}")
# Out:
# Mejor valor de alpha encontrado: 0.002072921779595374
# Mejor valor de l1_ratio encontrado: 0.7

# %%
# Parámetros del modelo
df_coeficientes = pd.DataFrame(
                        {'predictor': X_train.columns,
                         'coef': modelo.coef_.flatten()}
                  )

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')
plt.xticks(rotation=90, ha='right', size=10)
ax.set_xlabel('feature')
ax.set_ylabel('parámetros')
ax.set_title('Parámetros del modelo');
# Out:
# <ipython-input-74-2578e2451d15>:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   ax.stem(df_coeficientes.predictor, df_coeficientes.coef, markerfmt=' ')

# %%
# Predicciones test

predicciones = modelo.predict(X=X_test)
predicciones = predicciones.flatten()

# %%
# Error de test del modelo 

rmse_elastic = mean_squared_error(
                y_true  = y_test,
                y_pred  = predicciones,
                squared = False
               )
print("")
print(f"El error (rmse) de test es: {rmse_elastic}")
# Out:
# El error (rmse) de test es: 0.4469628952553584

# %%
R2 = metrics.r2_score(y_test, predicciones)
R2
# Out:
# 0.818878318233028

# %%
df_comparacion = pd.DataFrame({
                    'modelo': ['LinearRegression', 'Ridge', 'Lasso', 'Elastic-net'],
                    'test rmse': [rmse_ols, rmse_ridge, rmse_lasso, rmse_elastic]
                 })

fig, ax = plt.subplots(figsize=(15, 10))
df_comparacion.set_index('modelo').plot(kind='barh', ax=ax)
ax.set_xlabel('rmse')
ax.set_ylabel('modelo')
ax.set_title('Comparación de modelos');

# %% [markdown]
# ### Bibliografía
# * https://www.kaggle.com/nehalbirla/vehicle-dataset-from-cardekho
# * https://www.kaggle.com/jaysoftic/car-valuation-prediction
# * Regularización Ridge, Lasso y Elastic Net con Python by Joaquín Amat Rodrigo, available under a Attribution 4.0 International (CC BY 4.0) at https://www.cienciadedatos.net/documentos/py14-ridge-lasso-elastic-net-python.html
